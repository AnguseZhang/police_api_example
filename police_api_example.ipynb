# %%
import requests

# %%
j = requests.get("https://data.police.uk/api/forces")

# %%
j
# Out:
# <Response [200]>

# %%
j.json()
# Out:
# [{'id': 'avon-and-somerset', 'name': 'Avon and Somerset Constabulary'},
#  {'id': 'bedfordshire', 'name': 'Bedfordshire Police'},
#  {'id': 'cambridgeshire', 'name': 'Cambridgeshire Constabulary'},
#  {'id': 'cheshire', 'name': 'Cheshire Constabulary'},
#  {'id': 'city-of-london', 'name': 'City of London Police'},
#  {'id': 'cleveland', 'name': 'Cleveland Police'},
#  {'id': 'cumbria', 'name': 'Cumbria Constabulary'},
#  {'id': 'derbyshire', 'name': 'Derbyshire Constabulary'},
#  {'id': 'devon-and-cornwall', 'name': 'Devon & Cornwall Police'},
#  {'id': 'dorset', 'name': 'Dorset Police'},
#  {'id': 'durham', 'name': 'Durham Constabulary'},
#  {'id': 'dyfed-powys', 'name': 'Dyfed-Powys Police'},
#  {'id': 'essex', 'name': 'Essex Police'},
#  {'id': 'gloucestershire', 'name': 'Gloucestershire Constabulary'},
#  {'id': 'greater-manchester', 'name': 'Greater Manchester Police'},
#  {'id': 'gwent', 'name': 'Gwent Police'},
#  {'id': 'hampshire', 'name': 'Hampshire Constabulary'},
# ...

# %%
import requests

# %% [markdown]
# https://data.police.uk/docs/method/crime-street/

# %%
j=requests.get(url="https://data.police.uk/api/crimes-street/all-crime", params={"lat" : "52.629729", "lng" : "-1.131592"} )

# %%
j.json()
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.632352',
#    'street': {'id': 883486, 'name': 'On or near Narborough Road North'},
#    'longitude': '-1.146549'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 95655411,
#   'location_subtype': '',
#   'month': '2021-10'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.634136',
#    'street': {'id': 883357, 'name': 'On or near Hotel Street'},
#    'longitude': '-1.134752'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 95655851,
#   'location_subtype': '',
#   'month': '2021-10'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.626225',
#    'street': {'id': 882374,
#     'name': 'On or near Further/higher Educational Building'},
#    'longitude': '-1.121346'},
#   'context': '',
# ...

# %%
j=requests.get(url="https://data.police.uk/api/crimes-street/all-crime", params={"poly" : "52.268,0.543:52.794,0.238:52.130,0.478"})

# %%
j.json()
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.430417',
#    'street': {'id': 558047, 'name': 'On or near Parking Area'},
#    'longitude': '0.413401'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 95611708,
#   'location_subtype': '',
#   'month': '2021-10'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.380535',
#    'street': {'id': 558097, 'name': "On or near Spooner's Drove"},
#    'longitude': '0.388799'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 95611761,
#   'location_subtype': '',
#   'month': '2021-10'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.703815',
#    'street': {'id': 998439, 'name': 'On or near Manor Drive'},
#    'longitude': '0.276217'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
# ...

# %%
import requests

# %%
https://data.police.uk/api/stops-force?force=avon-and-somerset&date=2017-01

# %%
j=requests.get(url="https://data.police.uk/docs/method/stops-force",
               params={"force" : "city-of-london"})

# %%
j=requests.get(url="https://data.police.uk/api/stops-force",
               params={"force" : "avon-and-somerset"})

# %%
j.json()
# Out:
# [{'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-10-29T23:03:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
# ...
